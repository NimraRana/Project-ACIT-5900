# %% [markdown]
# # Baseline - model applying clustering to complete web64 dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import time
#libraries for preprocessing
from nltk.tokenize import RegexpTokenizer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.util import ngrams

import string

#libraries for clustering
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram

from sklearn.decomposition import PCA

# %%
df = pd.read_csv('finalnouns.csv', index_col=0)

# %%
df.head()
# Out:
#                                                             url  \
# id
# KQe1r321ZaJY  https://www.abcnyheter.no/nyheter/norge/2021/1...
# jnegLMrLkawZ  https://www.ao.no/oslo-fergenes-siste-dag-pa-f...
# Jrb2vD34MbWL  https://www.abcnyheter.no/nyheter/verden/2021/...
# xkazKYRPqbJ0  https://norgeogverdensnytt.blogg.no/sandra-lyn...
# Vyb86KpPrevA  https://www.vg.no/nyheter/utenriks/i/V959MJ/ab...
#
#                                               og_url  \
# id
# KQe1r321ZaJY  https://www.abcnyheter.no/a/195798411/
# jnegLMrLkawZ          https://www.ao.no/5-128-204411
# Jrb2vD34MbWL  https://www.abcnyheter.no/a/195798410/
# xkazKYRPqbJ0                                     NaN
# Vyb86KpPrevA              https://www.vg.no/i/V959MJ
#
#                                    domain  \
# id
# KQe1r321ZaJY            www.abcnyheter.no
# jnegLMrLkawZ                    www.ao.no
# Jrb2vD34MbWL            www.abcnyheter.no
# xkazKYRPqbJ0  norgeogverdensnytt.blogg.no
# Vyb86KpPrevA                    www.vg.no
#
#                                                           title  \
# id
# KQe1r321ZaJY  Færre vil møte klimakrisen med tiltak som i ko...
# jnegLMrLkawZ  (+) Oslo-Fergenes siste dag på fjorden: – Det ...
# Jrb2vD34MbWL            25 drept i raid mot bankrøvere i Brasil
# xkazKYRPqbJ0                   Sandra Lyng (34) har fått korona
# Vyb86KpPrevA  Aborttilgangen tørker inn – nå skal Texas-love...
#
#                                                     description  \
# id
# KQe1r321ZaJY  Andelen som vil ha like kraftige tiltak mot kl...
# jnegLMrLkawZ  Siden 1917 har Oslo-Fergene fraktet turister o...
# Jrb2vD34MbWL  25 antatte medlemmer av en bande bankrøvere bl...
# xkazKYRPqbJ0  AV/   NorgeOgVerdensNytt   Foto:   Mauricio  E...
# Vyb86KpPrevA  MEMPHIS (VG) I sørstatene skyves nå kvinner fr...
#
#                                                         content  \
# id
# KQe1r321ZaJY  Samtidig som klimatoppmøtet i Glasgow starter,...
# jnegLMrLkawZ  Øyene, Ferger | Oslo-Fergenes siste dag på fjo...
# Jrb2vD34MbWL  50 politifolk deltok i operasjonen mot to gård...
# xkazKYRPqbJ0  AV/ NorgeOgVerdensNytt Foto: Mauricio Evensen ...
# Vyb86KpPrevA  FORBEREDELSER: Joy Evans er såkalt «patient ed...
#
#                                                        entities  \
# id
# KQe1r321ZaJY  ['Glasgow', 'Fokus', 'Norge', 'Klimatoppmøtet'...
# jnegLMrLkawZ                                                NaN
# Jrb2vD34MbWL  ['bandemedlemmene', 'Rodolfo Morotti Fernandes...
# xkazKYRPqbJ0  ['Mauricio Evensen', 'Sandra Lyng', 'Lyngs', '...
# Vyb86KpPrevA  ['Texas', 'Roe', 'Wade', 'Memphis', 'Webb', 'H...
#
#                              authors  paywall  fb_total  ...  is_homepage  \
# id                                                       ...
# KQe1r321ZaJY                     NaN      NaN         0  ...          NaN
# jnegLMrLkawZ      ['Sevda Barazesh']      1.0         1  ...          NaN
# Jrb2vD34MbWL                     NaN      NaN         0  ...          NaN
# xkazKYRPqbJ0  ['norgeogverdensnytt']      NaN         0  ...          NaN
# Vyb86KpPrevA                     NaN      NaN         0  ...          NaN
#
#               is_document  http_code  feeds cat_id  cat_score  \
# id
# KQe1r321ZaJY        False        200    NaN  154.0   0.963856
# jnegLMrLkawZ        False        200    NaN    NaN        NaN
# Jrb2vD34MbWL        False        200    NaN   65.0   1.000018
# xkazKYRPqbJ0        False        200    NaN  127.0   0.714142
# Vyb86KpPrevA        False        200    NaN  168.0   0.683313
#
#              outbound_link_ids  inbound_link_ids  \
# id
# KQe1r321ZaJY               NaN               NaN
# jnegLMrLkawZ               NaN  ['LDdwm7PORa1Y']
# Jrb2vD34MbWL               NaN               NaN
# xkazKYRPqbJ0               NaN               NaN
# Vyb86KpPrevA  ['nXe0VD5vNbxr']  ['lNbW7oZOEbyg']
#
#                                                          tagss  \
# id
# KQe1r321ZaJY                                                []
# jnegLMrLkawZ                                                []
# Jrb2vD34MbWL                               [('Brasil', False)]
# xkazKYRPqbJ0                           [('Sandra Lyng', True)]
# Vyb86KpPrevA  [('Texas-loven', False), ('Høyesterett', False)]
#
#                                                          Nounss
# id
# KQe1r321ZaJY  ['Færre', 'klimakrisen', 'tiltak', 'koronapand...
# jnegLMrLkawZ                ['Oslo-Fergenes', 'dag', 'fjorden']
# Jrb2vD34MbWL                   ['raid', 'bankrøvere', 'Brasil']
# xkazKYRPqbJ0                                 ['Sandra', 'Lyng']
# Vyb86KpPrevA   ['Aborttilgangen', 'Texas-loven', 'Høyesterett']
#
# [5 rows x 33 columns]

# %%
print(df.shape)# convert published date to datetime
date_format = '%Y-%m-%dT%H:%M:%S'

# make features for hour and day
df['pub_day'] = pd.to_datetime(df.pub_date, format=date_format).dt.date
df['pub_hour'] = pd.to_datetime(df.pub_date, format=date_format).dt.hour
# Out:
# (87638, 34)

# %% [markdown]
# # Preprocessing

# %%
#initialize tokenizer and stemmer
tokenizer = RegexpTokenizer('[^\W\d_]+')
stemmer = SnowballStemmer("norwegian", ignore_stopwords=True)

def clean(doc):   
    doc_ = doc

    # make all lower case
    doc_ = doc_.lower()
    
    # tokenize text. regex includes alphabetic characters, including letters with accents. 
    # excludes punctuation and numbers.
    words = tokenizer.tokenize(doc_)
    
    
    # do not stem stopwords
    stems = list(map(stemmer.stem, words))

    doc_ = " ".join(stems)
    
    # count number of words 
    n_words = len(words)

    return doc_#, title_words, n_words

# %%
#clean Nounss
df['Nounss_clean'] = df.Nounss.apply(clean)

# read stopwords from file
sw = [line.strip("\n") for line in open("/Users/nimrarana/Downloads/norwegian_stopwords.txt", "r")]

# initialize vectorizer to count words, ignoring norwegian stopwords
vectorizer = CountVectorizer(stop_words=sw)

# initialize TF-IDF counter
tfidf = TfidfTransformer()

# %% [markdown]
# # Clustering of full dataset

# %%
# cluster per day
dates = df.pub_day.unique()

cluster_id_list = []
for dt in dates:
    print(dt)
    df_sub = df[df.pub_day == dt]
    print('%d articles included in clustering' % df_sub.shape[0])
# Out:
# 2021-10-31
# 4612 articles included in clustering
# 2021-11-01
# 6782 articles included in clustering
# 2021-11-02
# 7064 articles included in clustering
# 2021-11-03
# 7012 articles included in clustering
# 2021-11-04
# 7308 articles included in clustering
# 2021-11-05
# 6896 articles included in clustering
# 2021-11-06
# 4479 articles included in clustering
# 2021-11-07
# 4677 articles included in clustering
# 2021-11-08
# 6869 articles included in clustering
# 2021-11-09
# 6628 articles included in clustering
# 2021-11-10
# 6999 articles included in clustering
# 2021-11-11
# 6969 articles included in clustering
# 2021-11-12
# 6870 articles included in clustering
# 2021-11-13
# 4473 articles included in clustering

# %%
# cluster per day
dates = df.pub_day.unique()

cluster_id_list = []
for dt in dates:
    print(dt)
    df_sub = df[df.pub_day == dt]
    print('%d articles included in clustering' % df_sub.shape[0])

    # fit vectorizer to corpus of titles
    vectorizer.fit(df_sub.Nounss_clean.values)

    # convert data to word counts
    word_count_matrix = vectorizer.transform(df_sub.Nounss_clean.values)
    n_articles = word_count_matrix.shape[0]
    print('Word count vectorization has %d entries and %d words' % word_count_matrix.shape)

    # fit and transform to titles corpus
    word_term_frequency_matrix = tfidf.fit_transform(word_count_matrix)
    
    # create dataframe from TF-IDF values
    tf = pd.DataFrame(word_term_frequency_matrix.toarray())
    
    # run PCA
    all_pca = PCA(n_components=int(n_articles*0.9), svd_solver='randomized')

    bt = time.time()
    all_pcs = all_pca.fit_transform(tf) #tf.iloc[:5000]
    et = time.time()
    print("time spent: %.2f s" % (et-bt))
    
    pc_95 = np.where(np.cumsum(all_pca.explained_variance_ratio_)>0.95)[0][0]

    ac = AgglomerativeClustering(n_clusters=pc_95, linkage='complete')
    clusters = ac.fit_predict(tf)
    
    # create cluster id from day of year and cluster id
    df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)

    cluster_id_list.append(df_sub.pub_day.apply(lambda x: x.strftime('%j')) + '_' + df_sub.cluster_no.astype(str))
# Out:
# 2021-10-31
# 4612 articles included in clustering
# Word count vectorization has 4612 entries and 5258 words
# time spent: 73.73 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-01
# 6782 articles included in clustering
# Word count vectorization has 6782 entries and 7101 words
# time spent: 212.48 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-02
# 7064 articles included in clustering
# Word count vectorization has 7064 entries and 6867 words
# time spent: 247.47 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-03
# 7012 articles included in clustering
# Word count vectorization has 7012 entries and 7043 words
# time spent: 211.25 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-04
# 7308 articles included in clustering
# Word count vectorization has 7308 entries and 7270 words
# time spent: 236.17 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-05
# 6896 articles included in clustering
# Word count vectorization has 6896 entries and 6818 words
# time spent: 358.73 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-06
# 4479 articles included in clustering
# Word count vectorization has 4479 entries and 4986 words
# time spent: 57.20 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-07
# 4677 articles included in clustering
# Word count vectorization has 4677 entries and 5017 words
# time spent: 62.38 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-08
# 6869 articles included in clustering
# Word count vectorization has 6869 entries and 6850 words
# time spent: 1319.35 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-09
# 6628 articles included in clustering
# Word count vectorization has 6628 entries and 6734 words
# time spent: 226.86 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-10
# 6999 articles included in clustering
# Word count vectorization has 6999 entries and 6982 words
# time spent: 247.93 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-11
# 6969 articles included in clustering
# Word count vectorization has 6969 entries and 7133 words
# time spent: 291.72 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-12
# 6870 articles included in clustering
# Word count vectorization has 6870 entries and 6971 words
# time spent: 228.12 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)
# 2021-11-13
# 4473 articles included in clustering
# Word count vectorization has 4473 entries and 4908 words
# time spent: 86.99 s
# <ipython-input-22-814119ccbed4>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['cluster_no'] = pd.Series(clusters,index=df_sub.index)

# %%
np.cumsum(all_pca.explained_variance_ratio_)
# Out:
# array([0.0099121 , 0.01933457, 0.02725868, ..., 1.        , 1.        ,
#        1.        ])

# %%
df['cluster_id'] = pd.concat(cluster_id_list)

# %%
#save data
#df.to_csv('cop26_clust_noun.csv')

# %% [markdown]
# ## new dataset with a new feature with the assigned cluster id

# %%
#load dataset
df = pd.read_csv('cop26_clust_noun.csv', index_col=0)
df.head()
# Out:
#                                                             url  \
# id
# KQe1r321ZaJY  https://www.abcnyheter.no/nyheter/norge/2021/1...
# jnegLMrLkawZ  https://www.ao.no/oslo-fergenes-siste-dag-pa-f...
# Jrb2vD34MbWL  https://www.abcnyheter.no/nyheter/verden/2021/...
# xkazKYRPqbJ0  https://norgeogverdensnytt.blogg.no/sandra-lyn...
# Vyb86KpPrevA  https://www.vg.no/nyheter/utenriks/i/V959MJ/ab...
#
#                                               og_url  \
# id
# KQe1r321ZaJY  https://www.abcnyheter.no/a/195798411/
# jnegLMrLkawZ          https://www.ao.no/5-128-204411
# Jrb2vD34MbWL  https://www.abcnyheter.no/a/195798410/
# xkazKYRPqbJ0                                     NaN
# Vyb86KpPrevA              https://www.vg.no/i/V959MJ
#
#                                    domain  \
# id
# KQe1r321ZaJY            www.abcnyheter.no
# jnegLMrLkawZ                    www.ao.no
# Jrb2vD34MbWL            www.abcnyheter.no
# xkazKYRPqbJ0  norgeogverdensnytt.blogg.no
# Vyb86KpPrevA                    www.vg.no
#
#                                                           title  \
# id
# KQe1r321ZaJY  Færre vil møte klimakrisen med tiltak som i ko...
# jnegLMrLkawZ  (+) Oslo-Fergenes siste dag på fjorden: – Det ...
# Jrb2vD34MbWL            25 drept i raid mot bankrøvere i Brasil
# xkazKYRPqbJ0                   Sandra Lyng (34) har fått korona
# Vyb86KpPrevA  Aborttilgangen tørker inn – nå skal Texas-love...
#
#                                                     description  \
# id
# KQe1r321ZaJY  Andelen som vil ha like kraftige tiltak mot kl...
# jnegLMrLkawZ  Siden 1917 har Oslo-Fergene fraktet turister o...
# Jrb2vD34MbWL  25 antatte medlemmer av en bande bankrøvere bl...
# xkazKYRPqbJ0  AV/   NorgeOgVerdensNytt   Foto:   Mauricio  E...
# Vyb86KpPrevA  MEMPHIS (VG) I sørstatene skyves nå kvinner fr...
#
#                                                         content  \
# id
# KQe1r321ZaJY  Samtidig som klimatoppmøtet i Glasgow starter,...
# jnegLMrLkawZ  Øyene, Ferger | Oslo-Fergenes siste dag på fjo...
# Jrb2vD34MbWL  50 politifolk deltok i operasjonen mot to gård...
# xkazKYRPqbJ0  AV/ NorgeOgVerdensNytt Foto: Mauricio Evensen ...
# Vyb86KpPrevA  FORBEREDELSER: Joy Evans er såkalt «patient ed...
#
#                                                        entities  \
# id
# KQe1r321ZaJY  ['Glasgow', 'Fokus', 'Norge', 'Klimatoppmøtet'...
# jnegLMrLkawZ                                                NaN
# Jrb2vD34MbWL  ['bandemedlemmene', 'Rodolfo Morotti Fernandes...
# xkazKYRPqbJ0  ['Mauricio Evensen', 'Sandra Lyng', 'Lyngs', '...
# Vyb86KpPrevA  ['Texas', 'Roe', 'Wade', 'Memphis', 'Webb', 'H...
#
#                              authors  paywall  fb_total  ...  cat_score  \
# id                                                       ...
# KQe1r321ZaJY                     NaN      NaN         0  ...   0.963856
# jnegLMrLkawZ      ['Sevda Barazesh']      1.0         1  ...        NaN
# Jrb2vD34MbWL                     NaN      NaN         0  ...   1.000018
# xkazKYRPqbJ0  ['norgeogverdensnytt']      NaN         0  ...   0.714142
# Vyb86KpPrevA                     NaN      NaN         0  ...   0.683313
#
#               outbound_link_ids  inbound_link_ids  \
# id
# KQe1r321ZaJY                NaN               NaN
# jnegLMrLkawZ                NaN  ['LDdwm7PORa1Y']
# Jrb2vD34MbWL                NaN               NaN
# xkazKYRPqbJ0                NaN               NaN
# Vyb86KpPrevA   ['nXe0VD5vNbxr']  ['lNbW7oZOEbyg']
#
#                                                          tagss  \
# id
# KQe1r321ZaJY                                                []
# jnegLMrLkawZ                                                []
# Jrb2vD34MbWL                               [('Brasil', False)]
# xkazKYRPqbJ0                           [('Sandra Lyng', True)]
# Vyb86KpPrevA  [('Texas-loven', False), ('Høyesterett', False)]
#
#                                                          Nounss  \
# id
# KQe1r321ZaJY  ['Færre', 'klimakrisen', 'tiltak', 'koronapand...
# jnegLMrLkawZ                ['Oslo-Fergenes', 'dag', 'fjorden']
# Jrb2vD34MbWL                   ['raid', 'bankrøvere', 'Brasil']
# xkazKYRPqbJ0                                 ['Sandra', 'Lyng']
# Vyb86KpPrevA   ['Aborttilgangen', 'Texas-loven', 'Høyesterett']
#
#                                       title_clean     pub_day pub_hour  \
# id
# KQe1r321ZaJY  færr klimakris tiltak koronapandemi  2021-10-31       23
# jnegLMrLkawZ                  oslo ferg dag fjord  2021-10-31       23
# Jrb2vD34MbWL                raid bankrøver brasil  2021-10-31       23
# xkazKYRPqbJ0                           sandr lyng  2021-10-31       23
# Vyb86KpPrevA     aborttilgang tex lov høyesterett  2021-10-31       23
#
#                                      Nounss_clean  cluster_id
# id
# KQe1r321ZaJY  færr klimakris tiltak koronapandemi    304_1940
# jnegLMrLkawZ                  oslo ferg dag fjord    304_1097
# Jrb2vD34MbWL                raid bankrøver brasil    304_1870
# xkazKYRPqbJ0                           sandr lyng    304_2001
# Vyb86KpPrevA     aborttilgang tex lov høyesterett    304_1814
#
# [5 rows x 38 columns]

# %%
clust_size = df.groupby('cluster_id').Nounss_clean.count()
print('%d single-article stories' % np.sum(clust_size>1))
# Out:
# 16412 single-article stories

# %%
print('%d datapoint grouped into %d clusters' % (df.shape[0], df.cluster_id.nunique()))
# Out:
# 87638 datapoint grouped into 39942 clusters

# %% [markdown]
# ## Testing how well clusters are working

# %%
clust_size[clust_size>1].sort_values(ascending=False).tail()
# Out:
# cluster_id
# 312_1166    2
# 312_1164    2
# 312_1160    2
# 312_116     2
# 310_925     2
# Name: title_clean, dtype: int64

# %%
#Observing Cluster number 304_106
for Nounss in df[df.cluster_id=='304_106'].Nounss:
    print(Nounss)
# Out:
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Viking', 'Sarpsborg']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['Sarpsborg', 'formlaget', 'Viking', 'kamp']
# ['nedturen', 'Viking', 'Sarpsborg']
# ['Live', 'Viking', 'Sarpsborg']
# ['Viking-Sarpsborg', 'chat', 'Ingve', 'Bøe']
# ['Sarpsborg']
# ['Viking', 'Sarpsborg']

# %%
#Extracting domains of the articles in cluster 304_106
df[df.cluster_id=='304_106'].domain
# Out:
# id
# MYerRVjGweOB      www.altaposten.no
# l9avoLn6rbG1         www.adressa.no
# WZdPZWnylaKg         www.itromso.no
# ELe32Vzgrd69    www.framtidinord.no
# Jrb2vDyPJbWL          www.rbnett.no
# y1aKZ9gqzeQG              www.ht.no
# 4QbYvqzw0dzq             www.smp.no
# KQe1r30O3aJY     www.folkebladet.no
# Vyb86KGNmevA             www.nrk.no
# y5eVPnwz1bEP      www.nettavisen.no
# pmbkZXYN5azJ    www.framtidinord.no
# 4QbYvqzJpdzq         www.itromso.no
# olejq6XwWdjN              www.ht.no
# N1aMQWk65aWm      www.tipsbladet.no
# Vyb86KGxLevA     www.aftenbladet.no
# N1aMQWLnPaWm      www.dagsavisen.no
# y5eVPnX2MbEP     www.aftenbladet.no
# LDdwm7ovRa1Y              www.sa.no
# WZdPZWBllaKg              www.sa.no
# Name: domain, dtype: object

# %%
#Extracting titles of the articles in cluster 304_106
df[df.cluster_id=='304_106'].title
# Out:
# id
# MYerRVjGweOB    Sarpsborg stoppet formlaget Viking – vant sin ...
# l9avoLn6rbG1    Sarpsborg stoppet formlaget Viking – vant sin ...
# WZdPZWnylaKg    Sarpsborg stoppet formlaget Viking – vant sin ...
# ELe32Vzgrd69    Sarpsborg stoppet formlaget Viking – vant sin ...
# Jrb2vDyPJbWL    Sarpsborg stoppet formlaget Viking – vant sin ...
# y1aKZ9gqzeQG    Sarpsborg stoppet formlaget Viking – vant sin ...
# 4QbYvqzw0dzq    Sarpsborg stoppet formlaget Viking – vant sin ...
# KQe1r30O3aJY    Sarpsborg stoppet formlaget Viking – vant sin ...
# Vyb86KGNmevA                           Viking tapte mot Sarpsborg
# y5eVPnwz1bEP    Sarpsborg stoppet formlaget Viking – vant sin ...
# pmbkZXYN5azJ    Sarpsborg stoppet formlaget Viking - vant sin ...
# 4QbYvqzJpdzq    Sarpsborg stoppet formlaget Viking - vant sin ...
# olejq6XwWdjN    Sarpsborg stoppet formlaget Viking - vant sin ...
# N1aMQWk65aWm    Sarpsborg stoppet formlaget Viking - vant sin ...
# Vyb86KGxLevA     Så kom nedturen for Viking - tapte mot Sarpsborg
# N1aMQWLnPaWm    Live: Her følger du Viking mot Sarpsborg 08 di...
# y5eVPnX2MbEP    Direkte fra 18.00: Følg Viking-Sarpsborg og ch...
# LDdwm7ovRa1Y                         (+) Sterk Sarpsborg 08-seier
# WZdPZWBllaKg                   (+) Følg Viking - Sarpsborg 08 her
# Name: title, dtype: object

# %%
#Observing Cluster number 304_1
for Nounss in df[df.cluster_id=='304_1'].Nounss:
    print(Nounss)
# Out:
# ['helga', 'spøkelsesjakt']
# ['helgen']
# ['helga']
# ['sykehusavdeling', 'helgen']
# ['poeng', 'helgen']
# ['helga']

# %%
#Observing Cluster number 304_1036
for Nounss in df[df.cluster_id=='304_1036'].Nounss:
    print(Nounss)
# Out:
# ['gass', 'Norges', 'kjøttanlegg', 'ribbe', 'jul', 'Synd']
# ['gass', 'Norges', 'kjøttanlegg', 'ribbe', 'jul', 'Synd']
# ['gass', 'Norges', 'kjøttanlegg', 'ribbe', 'jul', 'Synd']
# ['gass', 'Norges', 'kjøttanlegg', 'ribbe', 'jul', 'Synd']
# ['gass', 'Norges', 'kjøttanlegg', 'ribbe', 'jul', 'Synd']
# ['gass', 'Norges', 'kjøttanlegg', 'ribbe', 'jul', 'Synd']
# ['gass', 'Norges', 'kjøttanlegg', 'ribbe', 'jul', 'Synd']

# %%
df[df.cluster_id=='304_1036'].domain
# Out:
# id
# YRdG5W40QaDz       www.nidaros.no
# BDbD9W4Ondl2        www.h-avis.no
# N1aMQW4XGaWm            www.sb.no
# 46dBL94n2a79          www.amta.no
# N1aMQW41PaWm            www.ta.no
# openrJ5O5e7A    www.nettavisen.no
# y1aKZ9nnGeQG    www.nettavisen.no
# Name: domain, dtype: object

# %%
#Observing Cluster number 304_136
df[df.cluster_id=='304_1036'].title
# Out:
# id
# YRdG5W40QaDz    Bånn gass på Norges største kjøttanlegg, men d...
# BDbD9W4Ondl2    (+) Bånn gass på Norges største kjøttanlegg, m...
# N1aMQW4XGaWm    (+) Bånn gass på Norges største kjøttanlegg – ...
# 46dBL94n2a79    Bånn gass på Norges største kjøttanlegg – men ...
# N1aMQW41PaWm    Bånn gass på Norges største kjøttanlegg – men ...
# openrJ5O5e7A    Bånn gass på Norges største kjøttanlegg – men ...
# y1aKZ9nnGeQG    Bånn gass på Norges største kjøttanlegg – men ...
# Name: title, dtype: object

# %%
df[df.cluster_id=='304_1'].domain
# Out:
# id
# olejq6zPWdjN               www.nrk.no
# YqaQ0gPXlenj    mammapaahjul.blogg.no
# BDbD9W31xdl2                www.tb.no
# 5xe7LV4QOa7r               www.nrk.no
# pmbkZXp2NazJ      geriatriks.blogg.no
# APdRoj9XEeGy     dinside.dagbladet.no
# Name: domain, dtype: object

# %%
for Nounss in df[df.cluster_id=='304_1'].Nounss:
    print(Nounss)

# %%
for Nounss in df[df.cluster_id=='304_1017'].Nounss:
    print(Nounss)
# Out:
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['Abo', 'brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene']
# ['brusen', 'butikkhyllene', '\u2060', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', '\u2060', 'folk']
# ['brusen', 'butikkhyllene', '\u2060', 'folk']
# ['brusen', 'butikkhyllene', '\u2060', 'folk']
# ['brusen', 'butikkhyllene', '\u2060', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']
# ['brusen', 'butikkhyllene', 'folk']

# %%
dff=df[df['Nounss'].str.contains('Øst-Europa', regex=False, case=False, na=False)]
dff
# Out:
#                                                             url  \
# id
# MvbmQNK63bYA  https://www.rb.no/smitten-sprer-seg-i-ost-euro...
# YqaQ0gY5qenj  https://www.nrk.no/nyheter/okt-koronasmitte-i-...
# zPdyr2ZJweQr  https://www.nettavisen.no/nyheter/utenriks/smi...
# 4QbYvqjrOdzq  https://www.rbnett.no/ntb/utenriks/2021/10/31/...
# y5eVPn4lBbEP  https://www.itromso.no/ntb/uriks/2021/10/31/Sm...
# oQeZVrkv2epZ  https://www.folkebladet.no/utenriks/2021/10/31...
# YqaQ0gYvMenj  https://www.ht.no/ntb/utenriks/2021/10/31/Smit...
# K9b6RKnzQbEv  https://www.altaposten.no/lokalt/NTB/NTB_utenr...
# olejq6EOzdjN  https://www.framtidinord.no/ntb/utenriks/2021/...
# QBeXopgq8dyK  https://www.smp.no/ntb/utenriks/2021/10/31/Smi...
# J0dN9WV5KbLO  https://www.adressa.no/nyheter/utenriks/2021/1...
# pmbkZjz1KazJ                      https://www.tv2.no/v/1701440/
#
#                                                   og_url               domain  \
# id
# MvbmQNK63bYA              https://www.rb.no/5-43-1673392            www.rb.no
# YqaQ0gY5qenj                                         NaN           www.nrk.no
# zPdyr2ZJweQr  https://www.nettavisen.no/12-95-3424199010    www.nettavisen.no
# 4QbYvqjrOdzq                                         NaN        www.rbnett.no
# y5eVPn4lBbEP                                         NaN       www.itromso.no
# oQeZVrkv2epZ                                         NaN   www.folkebladet.no
# YqaQ0gYvMenj                                         NaN            www.ht.no
# K9b6RKnzQbEv                                         NaN    www.altaposten.no
# olejq6EOzdjN                                         NaN  www.framtidinord.no
# QBeXopgq8dyK                                         NaN           www.smp.no
# J0dN9WV5KbLO                                         NaN       www.adressa.no
# pmbkZjz1KazJ                                         NaN           www.tv2.no
#
#                                                    title  \
# id
# MvbmQNK63bYA              Smitten sprer seg i Øst-Europa
# YqaQ0gY5qenj               Økt koronasmitte i Øst-Europa
# zPdyr2ZJweQr              Smitten sprer seg i Øst-Europa
# 4QbYvqjrOdzq              Smitten sprer seg i Øst-Europa
# y5eVPn4lBbEP              Smitten sprer seg i Øst-Europa
# oQeZVrkv2epZ              Smitten sprer seg i Øst-Europa
# YqaQ0gYvMenj              Smitten sprer seg i Øst-Europa
# K9b6RKnzQbEv              Smitten sprer seg i Øst-Europa
# olejq6EOzdjN              Smitten sprer seg i Øst-Europa
# QBeXopgq8dyK              Smitten sprer seg i Øst-Europa
# J0dN9WV5KbLO              Smitten sprer seg i Øst-Europa
# pmbkZjz1KazJ  TV 2 forklarer: Migrantkrisen i Øst-Europa
#
#                                                     description  \
# id
# MvbmQNK63bYA  Koronasmitten stiger raskt i land som Slovakia...
# YqaQ0gY5qenj  Tsjekkia registrerte søndag mer enn 5.000 smit...
# zPdyr2ZJweQr  Koronasmitten stiger raskt i land som Slovakia...
# 4QbYvqjrOdzq  Koronasmitten stiger raskt i land som Slovakia...
# y5eVPn4lBbEP  Koronasmitten stiger raskt i land som Slovakia...
# oQeZVrkv2epZ  Koronasmitten stiger raskt i land som Slovakia...
# YqaQ0gYvMenj  Koronasmitten stiger raskt i land som Slovakia...
# K9b6RKnzQbEv  Koronasmitten stiger raskt i land som Slovakia...
# olejq6EOzdjN  Koronasmitten stiger raskt i land som Slovakia...
# QBeXopgq8dyK  Koronasmitten stiger raskt i land som Slovakia...
# J0dN9WV5KbLO  Koronasmitten stiger raskt i land som Slovakia...
# pmbkZjz1KazJ  Tusenvis av flyktninger og migranter har reist...
#
#                                                         content  \
# id
# MvbmQNK63bYA  Koronasmitten stiger raskt i land som Slovakia...
# YqaQ0gY5qenj  Økt koronasmitte i Øst-Europa Tsjekkia registr...
# zPdyr2ZJweQr  Koronasmitten stiger raskt i land som Slovakia...
# 4QbYvqjrOdzq  Utenriks Tsjekkia registrerte søndag mer enn 5...
# y5eVPn4lBbEP  uriks Tsjekkia registrerte søndag mer enn 5.00...
# oQeZVrkv2epZ  utenriks Tsjekkia registrerte søndag mer enn 5...
# YqaQ0gYvMenj  utenriks Tsjekkia registrerte søndag mer enn 5...
# K9b6RKnzQbEv  NTB utenriks Tsjekkia registrerte søndag mer e...
# olejq6EOzdjN  utenriks Tsjekkia registrerte søndag mer enn 5...
# QBeXopgq8dyK  Smitten sprer seg i Øst-Europa - Sunnmørsposte...
# J0dN9WV5KbLO  - «Ånnen» passer på dyrene og derfor er hun ik...
# pmbkZjz1KazJ  På TV 2s nettsider bruker vi og våre partnere ...
#
#                                                        entities  \
# id
# MvbmQNK63bYA  ['Polen', 'Slovakia', 'Tsjekkia', 'Visehelsemi...
# YqaQ0gY5qenj  ['Øst-Europa Tsjekkia', 'Polen', 'Slovakia', '...
# zPdyr2ZJweQr  ['Polen', 'Slovakia', 'Tsjekkia', 'Visehelsemi...
# 4QbYvqjrOdzq  ['Polen', 'Utenriks Tsjekkia', 'Visehelseminis...
# y5eVPn4lBbEP  ['Polen', 'Tsjekkia', 'Visehelseminister Walde...
# oQeZVrkv2epZ  ['Polen', 'Tsjekkia', 'Visehelseminister Walde...
# YqaQ0gYvMenj  ['Polen', 'Tsjekkia', 'Visehelseminister Walde...
# K9b6RKnzQbEv  ['NTB', 'Polen', 'Tsjekkia', 'Visehelseministe...
# olejq6EOzdjN  ['Polen', 'Tsjekkia', 'Visehelseminister Walde...
# QBeXopgq8dyK                                                NaN
# J0dN9WV5KbLO  ['Trondheim', 'Johnson', 'Polen', 'Bente', 'Ma...
# pmbkZjz1KazJ                                                NaN
#
#                               authors  paywall  fb_total  ...  cat_score  \
# id                                                        ...
# MvbmQNK63bYA                  ['NTB']      NaN         0  ...   0.314579
# YqaQ0gY5qenj                  ['NRK']      NaN         0  ...   0.483529
# zPdyr2ZJweQr  ['NTB', 'NTB Tips meg']      NaN         0  ...   0.309345
# 4QbYvqjrOdzq        ['(NTB) NTB-DPA']      NaN         0  ...   0.605510
# y5eVPn4lBbEP        ['(NTB) NTB-DPA']      NaN         0  ...   0.409833
# oQeZVrkv2epZ        ['(NTB) NTB-DPA']      NaN         0  ...   0.605510
# YqaQ0gYvMenj        ['(NTB) NTB-DPA']      NaN         0  ...   0.605510
# K9b6RKnzQbEv        ['(NTB) NTB-DPA']      NaN         0  ...   0.804374
# olejq6EOzdjN        ['(NTB) NTB-DPA']      NaN         0  ...   0.605510
# QBeXopgq8dyK        ['(NTB) NTB-DPA']      NaN         0  ...        NaN
# J0dN9WV5KbLO        ['(NTB) NTB-DPA']      NaN         0  ...   0.440711
# pmbkZjz1KazJ                      NaN      NaN         0  ...        NaN
#
#               outbound_link_ids  inbound_link_ids                    tagss  \
# id
# MvbmQNK63bYA                NaN               NaN  [('Øst-Europa', False)]
# YqaQ0gY5qenj                NaN               NaN  [('Øst-Europa', False)]
# zPdyr2ZJweQr                NaN               NaN  [('Øst-Europa', False)]
# 4QbYvqjrOdzq                NaN               NaN  [('Øst-Europa', False)]
# y5eVPn4lBbEP                NaN               NaN  [('Øst-Europa', False)]
# oQeZVrkv2epZ                NaN               NaN  [('Øst-Europa', False)]
# YqaQ0gYvMenj                NaN               NaN  [('Øst-Europa', False)]
# K9b6RKnzQbEv                NaN               NaN  [('Øst-Europa', False)]
# olejq6EOzdjN                NaN               NaN  [('Øst-Europa', False)]
# QBeXopgq8dyK                NaN               NaN  [('Øst-Europa', False)]
# J0dN9WV5KbLO                NaN               NaN  [('Øst-Europa', False)]
# pmbkZjz1KazJ                NaN               NaN  [('Øst-Europa', False)]
#
#                                              Nounss               title_clean  \
# id
# MvbmQNK63bYA              ['Smitten', 'Øst-Europa']           smitt øst europ
# YqaQ0gY5qenj                         ['Øst-Europa']                 øst europ
# zPdyr2ZJweQr              ['Smitten', 'Øst-Europa']           smitt øst europ
# 4QbYvqjrOdzq              ['Smitten', 'Øst-Europa']           smitt øst europ
# y5eVPn4lBbEP              ['Smitten', 'Øst-Europa']           smitt øst europ
# oQeZVrkv2epZ              ['Smitten', 'Øst-Europa']           smitt øst europ
# YqaQ0gYvMenj              ['Smitten', 'Øst-Europa']           smitt øst europ
# K9b6RKnzQbEv              ['Smitten', 'Øst-Europa']           smitt øst europ
# olejq6EOzdjN              ['Smitten', 'Øst-Europa']           smitt øst europ
# QBeXopgq8dyK              ['Smitten', 'Øst-Europa']           smitt øst europ
# J0dN9WV5KbLO              ['Smitten', 'Øst-Europa']           smitt øst europ
# pmbkZjz1KazJ  ['TV', 'Migrantkrisen', 'Øst-Europa']  tv migrantkris øst europ
#
#                  pub_day pub_hour              Nounss_clean  cluster_id
# id
# MvbmQNK63bYA  2021-10-31       21           smitt øst europ     304_650
# YqaQ0gY5qenj  2021-10-31       21                 øst europ     304_650
# zPdyr2ZJweQr  2021-10-31       20           smitt øst europ     304_650
# 4QbYvqjrOdzq  2021-10-31       20           smitt øst europ     304_650
# y5eVPn4lBbEP  2021-10-31       20           smitt øst europ     304_650
# oQeZVrkv2epZ  2021-10-31       20           smitt øst europ     304_650
# YqaQ0gYvMenj  2021-10-31       20           smitt øst europ     304_650
# K9b6RKnzQbEv  2021-10-31       20           smitt øst europ     304_650
# olejq6EOzdjN  2021-10-31       20           smitt øst europ     304_650
# QBeXopgq8dyK  2021-10-31       20           smitt øst europ     304_650
# J0dN9WV5KbLO  2021-10-31       20           smitt øst europ     304_650
# pmbkZjz1KazJ  2021-11-10       20  tv migrantkris øst europ    314_2820
#
# [12 rows x 38 columns]

# %%
df[df.cluster_id=='304_650'].domain
# Out:
# id
# MvbmQNK63bYA              www.rb.no
# YqaQ0gY5qenj             www.nrk.no
# zPdyr2ZJweQr      www.nettavisen.no
# 4QbYvqjrOdzq          www.rbnett.no
# y5eVPn4lBbEP         www.itromso.no
# oQeZVrkv2epZ     www.folkebladet.no
# YqaQ0gYvMenj              www.ht.no
# K9b6RKnzQbEv      www.altaposten.no
# olejq6EOzdjN    www.framtidinord.no
# QBeXopgq8dyK             www.smp.no
# J0dN9WV5KbLO         www.adressa.no
# Name: domain, dtype: object

# %%
for Nounss in df[df.cluster_id=='304_650'].Nounss:
    print(Nounss)
# Out:
# ['Smitten', 'Øst-Europa']
# ['Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']
# ['Smitten', 'Øst-Europa']

# %% [markdown]
# # Dictionary of all the articles more than 1 domain

# %%
#stories with more than one article
df[df.cluster_id.isin(clust_size[clust_size>1].index)]

# make a dictionary for all clusters with size>1
# collect all unique domains within that cluster
clust_domain_dict = {}
for cluster in clust_size[clust_size>1].index[:60]:
    clust_domain_dict[cluster] = df[df.cluster_id==cluster].domain.unique()

# %%
clust_domain_dict
# Out:
# {'304_0': array(['www.framtidinord.no', 'www.ha-halden.no', 'www.fjt.no',
#         'www.itromso.no'], dtype=object),
#  '304_1': array(['www.nrk.no', 'mammapaahjul.blogg.no', 'www.tb.no',
#         'geriatriks.blogg.no', 'dinside.dagbladet.no'], dtype=object),
#  '304_10': array(['www.sandnesposten.no', 'www.nrk.no'], dtype=object),
#  '304_100': array(['www.mitthammerfest.no', 'www.ifinnmark.no', 'www.sb.no'],
#        dtype=object),
#  '304_1000': array(['www.ta.no', 'www.adressa.no'], dtype=object),
#  '304_101': array(['www.adressa.no', 'www.sb.no', 'www.indre.no'], dtype=object),
#  '304_1015': array(['www.dagbladet.no', 'www.engelskeklubber.com'], dtype=object),
#  '304_1016': array(['www.rbnett.no', 'www.ba.no', 'www.hardanger-folkeblad.no'],
#        dtype=object),
#  '304_1017': array(['www.pd.no', 'www.gd.no', 'www.tvedestrandsposten.no', 'www.ao.no',
#         'www.ranablad.no', 'www.sa.no', 'www.h-a.no', 'www.amta.no',
#         'www.op.no', 'www.ha-halden.no', 'www.moss-avis.no', 'www.oa.no',
#         'www.nettavisen.no', 'www.nidaros.no', 'www.f-b.no', 'www.an.no',
#         'www.rablad.no', 'www.ta.no', 'www.ifinnmark.no', 'www.dt.no',
#         'www.rb.no', 'www.iharstad.no', 'www.nordlys.no', 'www.rha.no',
#         'www.sb.no', 'www.bygdeposten.no', 'www.laagendalsposten.no',
#         'www.fremover.no', 'www.avisa-valdres.no'], dtype=object),
#  '304_1019': array(['e24.no'], dtype=object),
#  '304_102': array(['www.ta.no', 'www.rb.no', 'www.tv2.no'], dtype=object),
#  '304_1020': array(['www.tb.no', 'www.nrk.no'], dtype=object),
#  '304_1028': array(['www.lofotposten.no', 'www.vol.no', 'www.blv.no'], dtype=object),
#  '304_103': array(['stralende-tanker.com', 'resett.no'], dtype=object),
#  '304_1036': array(['www.nidaros.no', 'www.h-avis.no', 'www.sb.no', 'www.amta.no',
#         'www.ta.no', 'www.nettavisen.no'], dtype=object),
#  '304_1039': array(['www.dt.no'], dtype=object),
#  '304_104': array(['www.avisa-st.no', 'www.ba.no', 'www.ht.no'], dtype=object),
#  '304_1043': array(['www.ostlendingen.no'], dtype=object),
#  '304_1044': array(['www.vg.no'], dtype=object),
#  '304_1047': array(['www.isandnessjoen.no', 'www.nord24.no', 'www.nordlys.no'],
#        dtype=object),
#  '304_1048': array(['www.dagbladet.no', 'www.seher.no'], dtype=object),
#  '304_1049': array(['www.rb.no'], dtype=object),
#  '304_105': array(['www.nordlys.no', 'www.lister24.no', 'realmadridnorge.no',
#         'www.byas.no'], dtype=object),
#  '304_1051': array(['www.firda.no'], dtype=object),
#  '304_1053': array(['www.aftenbladet.no', 'www.jbl.no'], dtype=object),
#  '304_1054': array(['www.vg.no', 'www.bt.no', 'www.aftenposten.no'], dtype=object),
#  '304_1055': array(['www.aftenposten.no', 'www.aftenbladet.no', 'www.bt.no',
#         'www.vg.no'], dtype=object),
#  '304_1057': array(['resett.no', 'www.dagsavisen.no', 'www.e-tv.no',
#         'www.extraavisen.no', 'www.nrk.no', 'www.abcnyheter.no'],
#        dtype=object),
#  '304_1058': array(['www.ifinnmark.no', 'www.nordlys.no', 'www.finnmarksposten.no'],
#        dtype=object),
#  '304_106': array(['www.altaposten.no', 'www.adressa.no', 'www.itromso.no',
#         'www.framtidinord.no', 'www.rbnett.no', 'www.ht.no', 'www.smp.no',
#         'www.folkebladet.no', 'www.nrk.no', 'www.nettavisen.no',
#         'www.tipsbladet.no', 'www.aftenbladet.no', 'www.dagsavisen.no',
#         'www.sa.no'], dtype=object),
#  '304_1061': array(['www.ht.no', 'malviknytt.no'], dtype=object),
#  '304_1065': array(['www.ostlendingen.no'], dtype=object),
#  '304_1066': array(['www.varingen.no'], dtype=object),
#  '304_1069': array(['www.mittkongsvinger.no', 'www.blv.no'], dtype=object),
#  '304_107': array(['www.document.no', 'www.bygg.no'], dtype=object),
#  '304_1071': array(['www.sporenbiolog.no'], dtype=object),
#  '304_1073': array(['www.aftenposten.no', 'www.itromso.no'], dtype=object),
#  '304_1075': array(['www.nrk.no'], dtype=object),
#  '304_1076': array(['www.smaalenene.no', 'www.vestbyavis.no', 'www.ht.no',
#         'www.ringblad.no', 'www.lister24.no', 'www.ha-halden.no'],
#        dtype=object),
#  '304_108': array(['www.nrk.no', 'www.pd.no'], dtype=object),
#  '304_1086': array(['www.adressa.no'], dtype=object),
#  '304_1087': array(['www.mcsiden.no'], dtype=object),
#  '304_1089': array(['www.tu.no', 'www.dn.no'], dtype=object),
#  '304_109': array(['www.sb.no', 'www.f-b.no'], dtype=object),
#  '304_1091': array(['randaberg24.no', 'www.oblad.no'], dtype=object),
#  '304_1092': array(['www.glomdalen.no', 'www.jbl.no'], dtype=object),
#  '304_1093': array(['www.nettavisen.no', 'www.altaposten.no', 'www.ht.no',
#         'www.framtidinord.no', 'www.folkebladet.no', 'www.adressa.no',
#         'www.rbnett.no', 'www.smp.no', 'www.itromso.no'], dtype=object),
#  '304_1094': array(['www.nrk.no'], dtype=object),
#  '304_1095': array(['www.tv2.no'], dtype=object),
#  '304_1096': array(['www.nrk.no', 'www.ao.no'], dtype=object),
#  '304_1097': array(['www.ao.no', 'www.aftenposten.no'], dtype=object),
#  '304_1098': array(['www.amta.no', 'www.ta.no', 'www.ao.no', 'www.kv.no',
#         'www.noblad.no'], dtype=object),
#  '304_1099': array(['www.kunstveggen.no'], dtype=object),
#  '304_11': array(['nye-troms.no', 'www.ha-halden.no', 'www.sa.no'], dtype=object),
#  '304_110': array(['www.sa.no', 'www.ba.no'], dtype=object),
#  '304_1100': array(['nye-troms.no', 'www.nettavisen.no'], dtype=object),
#  '304_1101': array(['www.kristiansandgk.no', 'kristiansandgk.no'], dtype=object),
#  '304_1102': array(['rorosnytt.no'], dtype=object),
#  '304_1104': array(['www.morenytt.no', 'www.smp.no'], dtype=object),
#  '304_1107': array(['sportsbibelen.no', 'www.tipsbladet.no'], dtype=object)}

# %%
import pandas as pd
df = pd.read_csv('cop26_clust_noun.csv', index_col=0)

# %%
df.groupby('cluster_id').size()
# Out:
# cluster_id
# 304_0       4
# 304_1       6
# 304_10      2
# 304_100     3
# 304_1000    2
#            ..
# 317_995     2
# 317_996     2
# 317_997     6
# 317_998     2
# 317_999     1
# Length: 39942, dtype: int64
